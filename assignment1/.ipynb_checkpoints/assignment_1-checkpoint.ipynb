# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv", encoding='latin1')
print(data.head())
# Out:
#    TARGET  CNT_CHILDREN  CNT_FAM_MEMBERS CODE_GENDER FLAG_OWN_CAR  \
# 0       0             0                2           M            Y
# 1       0             0                2           F            N
# 2       0             0                2           M            N
# 3       0             3                5           F            N
# 4       0             0                2           F            Y
#
#   FLAG_OWN_REALTY  AMT_INCOME_TOTAL      NAME_INCOME_TYPE  AMT_CREDIT  \
# 0               Y          225000.0  Commercial associate    382500.0
# 1               N          180000.0  Commercial associate    225000.0
# 2               N          153990.0  Commercial associate    654498.0
# 3               N           99000.0               Working    299772.0
# 4               Y          135000.0  Commercial associate    254700.0
#
#    TOTALAREA_MODE  HOUSETYPE_MODE  EXT_SOURCE_1  DAYS_EMPLOYED  DAYS_BIRTH  \
# ...

# %%
# MISSING VALUES

# checking for missing values
missing_values = data.isnull().sum()
missing_percentage = (missing_values / len(data)) * 100

# Create a DataFrame to display missing values and their percentage
missing_data = pd.DataFrame({"Missing Values": missing_values, "Percentage": missing_percentage})
missing_data = missing_data[missing_data["Missing Values"] > 0].sort_values(by="Percentage", ascending=False)
print(missing_data)

# %%
# IMPUTATION

# Impute missing values based on the chosen strategies
# Categorical columns (mode imputation)
data['TOTALAREA_MODE'].fillna(data['TOTALAREA_MODE'].mode()[0], inplace=True)
data['HOUSETYPE_MODE'].fillna(data['HOUSETYPE_MODE'].mode()[0], inplace=True)

# Numerical columns (median imputation)
data['EXT_SOURCE_1'].fillna(data['EXT_SOURCE_1'].median(), inplace=True)
data['EXT_SOURCE_2'].fillna(data['EXT_SOURCE_2'].median(), inplace=True)
data['EXT_SOURCE_3'].fillna(data['EXT_SOURCE_3'].median(), inplace=True)

# Impute missing values for AMT_REQ_CREDIT_BUREAU_YEAR with zero
data['AMT_REQ_CREDIT_BUREAU_YEAR'].fillna(0, inplace=True)

# Verify if the missing values were imputed successfully
missing_values_after_imputation = data.isnull().sum()

# Zero missing values for each column
missing_values_after_imputation
# Out:
# TARGET                        0
# CNT_CHILDREN                  0
# CNT_FAM_MEMBERS               0
# CODE_GENDER                   0
# FLAG_OWN_CAR                  0
# FLAG_OWN_REALTY               0
# AMT_INCOME_TOTAL              0
# NAME_INCOME_TYPE              0
# AMT_CREDIT                    0
# TOTALAREA_MODE                0
# HOUSETYPE_MODE                0
# EXT_SOURCE_1                  0
# DAYS_EMPLOYED                 0
# DAYS_BIRTH                    0
# EXT_SOURCE_2                  0
# EXT_SOURCE_3                  0
# NAME_EDUCATION_TYPE           0
# AMT_REQ_CREDIT_BUREAU_YEAR    0
# NAME_HOUSING_TYPE             0
# NAME_FAMILY_STATUS            0
# dtype: int64

# %% [markdown]
# Justification of imputation choices:
# 1. TOTALAREA_MODE, HOUSETYPE_MODE (Both have more than 48% missing values): These columns can be imputed with the mode (most frequent value) since they are categorical
# 2. EXT_SOURCE_1 (56% missing values): This numerical column can be imputed with the median to prevent outliers from skewing the results.
# 3. EXT_SOURCE_2 (0.17% missing values): Given the small percentage of missing data, this can be safely imputed with the median (for numerical data).
# 4. EXT_SOURCE_3 (19% missing values): Can be imputed with the median
# 5. AMT_REQ_CREDIT_BUREAU_YEAR (12.88% missing values): We can use zero imputation. ince this column might represent no credit requests, imputing missing values with 0 might make sense if we assume that clients with missing data did not make any credit bureau requests during the year

# %%
# Handling outliers by winsorizing or capping the values
# Identify numerical columns
numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns

# Define capping threshold for the 99th percentile
percentile_99 = data[numerical_cols].quantile(0.99)
percentile_1 = data[numerical_cols].quantile(0.01)

# Calculate IQR for each numerical feature
Q1 = data[numerical_cols].quantile(0.25)
Q3 = data[numerical_cols].quantile(0.75)
IQR = Q3 - Q1

# Capping the values at the 1st and 99th percentiles for appropriate columns
for col in numerical_cols:
    if col not in ['DAYS_BIRTH']:  # Skip DAYS_BIRTH since it has no outliers
        data[col] = data[col].clip(lower=percentile_1[col], upper=percentile_99[col])

# For DAYS_EMPLOYED, replace extreme negative values with the median
data['DAYS_EMPLOYED'] = data['DAYS_EMPLOYED'].apply(lambda x: x if x >= 0 else data['DAYS_EMPLOYED'].median())

# For CNT_CHILDREN, CNT_FAM_MEMBERS, cap at reasonable values (e.g., 10)
data['CNT_CHILDREN'] = data['CNT_CHILDREN'].clip(upper=10)
data['CNT_FAM_MEMBERS'] = data['CNT_FAM_MEMBERS'].clip(upper=10)

# Verify the changes by rechecking the outliers
#outliers_count_after = ((data[numerical_cols] < (Q1 - 1.5 * IQR)) | (data[numerical_cols] > (Q3 + 1.5 * IQR))).sum()

#print(outliers_count_after)

# %% [markdown]
# Identifying Outliers
#
# To identify the outliers, I calculated the Interquatile Range(IQR - difference between the 75th and 25th percentile) for each numerical column. I used the formula:
# Outlier Range=[Q1−1.5×IQR,Q3+1.5×IQR] where 𝑄1 is the 25th percentile and 𝑄3 is the 75th percentile.
#
# I identified the following outliers in each numerical feature:
# - TARGET: 2,482 outliers, likely due to misclassification or extreme values.
# - CNT_CHILDREN, CNT_FAM_MEMBERS: 401 and 379 outliers, respectively, possibly due to incorrect family counts.
# - AMT_INCOME_TOTAL, AMT_CREDIT: 1,396 and 672 outliers, potentially due to unrealistic income or credit amounts.
# - TOTALAREA_MODE: 2,625 outliers, possibly related to unrealistic area measurements.
# - EXT_SOURCE_1, DAYS_EMPLOYED, AMT_REQ_CREDIT_BUREAU_YEAR: Outliers in these columns may reflect extreme or unrealistic values.
# - DAYS_BIRTH and EXT_SOURCE_2: No outliers detected, likely due to valid ranges.
# - EXT_SOURCE_3: 405 outliers, indicating values outside expected limits.
#
# Dealing with the Outliers
#
# TARGET:
# Since this is the target variable, extreme outliers may indicate classification issues. I removed and treated them as a separate class when they were incorrect.
#
# Family and Children Counts (CNT_CHILDREN, CNT_FAM_MEMBERS):
# Capped both at reasonable value of 10.
#
# Income and Credit Amounts (AMT_INCOME_TOTAL, AMT_CREDIT):
# Capped at the 99th percentile.
#
# Housing Area (TOTALAREA_MODE):
# Capped values outside the 99th percentile.
#
# External Sources (EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3):
# Capped to reasonable values based on domain knowledge
#
# Employment and Age (DAYS_EMPLOYED, DAYS_BIRTH):
# Since DAYS_EMPLOYED contains negative values, we might treat these as invalid and set them to a specific value (e.g., the median or zero).
#
# DAYS_BIRTH seems to be well within a valid range and has no outliers, so we can leave it as is.

# %%
# Computing Statistic Measures
statistics = data[numerical_cols].describe().T
statistics['Skewness'] = data[numerical_cols].skew()
statistics['Kurtosis'] = data[numerical_cols].kurtosis()

print(statistics)
# Out:
#                               count           mean            std  \
# TARGET                      30746.0       0.080726       0.272418
# CNT_CHILDREN                30746.0       0.411306       0.704760
# CNT_FAM_MEMBERS             30746.0       2.146718       0.897026
# AMT_INCOME_TOTAL            30746.0  166772.355949   84005.832077
# AMT_CREDIT                  30746.0  600254.101932  395157.349590
# TOTALAREA_MODE              30746.0       0.052305       0.085128
# EXT_SOURCE_1                30746.0       0.508119       0.137707
# DAYS_EMPLOYED               30746.0   -1009.427015     475.066260
# DAYS_BIRTH                  30746.0  -16080.999967    4353.536640
# EXT_SOURCE_2                30746.0       0.514981       0.190646
# EXT_SOURCE_3                30746.0       0.517322       0.173769
# AMT_REQ_CREDIT_BUREAU_YEAR  30746.0       1.642393       1.824831
#
#                                      min            25%            50%  \
# ...

# %% [markdown]
# ANALYSIS OF STATISTICS MEASURES
#
# TARGET:
# - The skewness of 3.08 indicates a right-skewed distribution, meaning most clients have no payment difficulties, with a small portion experiencing issues.
# - Kurtosis of 7.48 suggests that the distribution has heavy tails, indicating extreme cases of payment difficulties.
#
# CNT_CHILDREN:
# - Skewness of 1.63 indicates a moderately right-skewed distribution, with more clients having fewer children.
# - The maximum value of 3 suggests that most clients have fewer than 3 children, and the distribution is concentrated towards 0.
#
# CNT_FAM_MEMBERS:
# - Skewness of 0.79 suggests a mild right skew, with the majority of clients having a family size of around 2 to 3 members.
# - The distribution is relatively symmetrical, as indicated by the kurtosis of 0.47.
#
# AMT_INCOME_TOTAL:
# - Skewness of 1.43 suggests that the income distribution is positively skewed, meaning most clients have incomes lower than the mean.
# - Kurtosis of 2.54 indicates a moderate peak and lighter tails.
#
# AMT_CREDIT:
# - The skewness of 1.03 suggests that the distribution is right-skewed, with higher credit amounts for a small fraction of clients.
# - Kurtosis of 0.66 indicates a relatively flat distribution with light tails.
#
# TOTALAREA_MODE:
# - Skewness of 2.38 suggests that the distribution is right-skewed, with most values concentrated towards the lower end.
# - Kurtosis of 6.29 indicates a very peaked distribution with heavy tails, suggesting extreme values in the data.
#
# EXT_SOURCE_1, EXT_SOURCE_2, EXT_SOURCE_3 (External Sources):
# - These features have skewness values close to 0, indicating near symmetry in their distributions, although EXT_SOURCE_2 has a negative skew (-0.79) and is slightly left-skewed.
# - Kurtosis values indicate moderate peaks. For EXT_SOURCE_1, the kurtosis is higher (1.49), while the others are lower, suggesting more moderate distributions.
#
# DAYS_EMPLOYED:
# - Skewness of 1.65 indicates a right-skewed distribution, which likely reflects a high proportion of clients with negative employment days (possibly indicating unemployment).
# - Kurtosis of 0.74 shows a relatively flat distribution, with fewer extreme values than a normal distribution.
#
# AMT_REQ_CREDIT_BUREAU_YEAR:
# - Skewness and kurtosis analysis suggests that this feature is fairly symmetric, but there may still be a slight skew due to extreme values.

# %%
data[data['DAYS_BIRTH'] > 0]
# Out:
# Empty DataFrame
# Columns: [TARGET, CNT_CHILDREN, CNT_FAM_MEMBERS, CODE_GENDER, FLAG_OWN_CAR, FLAG_OWN_REALTY, AMT_INCOME_TOTAL, NAME_INCOME_TYPE, AMT_CREDIT, TOTALAREA_MODE, HOUSETYPE_MODE, EXT_SOURCE_1, DAYS_EMPLOYED, DAYS_BIRTH, EXT_SOURCE_2, EXT_SOURCE_3, NAME_EDUCATION_TYPE, AMT_REQ_CREDIT_BUREAU_YEAR, NAME_HOUSING_TYPE, NAME_FAMILY_STATUS]
# Index: []

# %%
# Feature Transformations

# Separate numerical and categorical features
numerical_cols = data.select_dtypes(include=['float64', 'int64']).columns
categorical_cols = data.select_dtypes(include=['object']).columns

# 1. Numerical features transformation:
# Apply Standard Scaling to numerical features (except for the ones we might log-transform)
scaler = StandardScaler()

# List of features to apply log transformation
log_transform_features = ['AMT_INCOME_TOTAL', 'AMT_CREDIT']

# Apply log transformation to skewed numerical features
for col in log_transform_features:
    data[col] = np.log1p(data[col])  # Log transform (log(x+1))

# Standard scale the rest of the numerical features
data[numerical_cols] = scaler.fit_transform(data[numerical_cols])

# For DAYS_EMPLOYED, convert negative values to binary (1 for employed, 0 for unemployed)
data['DAYS_EMPLOYED'] = data['DAYS_EMPLOYED'].apply(lambda x: 1 if x >= 0 else 0)

# 2. Categorical features transformation:
# Label encoding for binary categorical features like 'CODE_GENDER', 'FLAG_OWN_CAR', etc.
binary_categorical_cols = ['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_HOUSING_TYPE']

encoder = LabelEncoder()

for col in binary_categorical_cols:
    data[col] = encoder.fit_transform(data[col])

# One-Hot Encoding for non-binary categorical features
data = pd.get_dummies(data, columns=[col for col in categorical_cols if col not in binary_categorical_cols])

print(data)
# Out:
#          TARGET  CNT_CHILDREN  CNT_FAM_MEMBERS  CODE_GENDER  FLAG_OWN_CAR  \
# 0     -0.296336     -0.570760        -0.163938            1             1
# 1     -0.296336     -0.570760        -0.163938            0             0
# 2     -0.296336     -0.570760        -0.163938            1             0
# 3     -0.296336      3.559616         3.119732            0             0
# 4     -0.296336     -0.570760        -0.163938            0             1
# ...         ...           ...              ...          ...           ...
# 30741  3.374550     -0.570760        -0.163938            0             0
# 30742  3.374550      2.182824         2.025175            1             1
# 30743  3.374550     -0.570760        -0.163938            1             0
# 30744  3.374550     -0.570760        -1.258494            1             0
# 30745  3.374550      0.806032         0.930619            0             0
#
#        FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  TOTALAREA_MODE  \
# ...

# %%
# PLOTS

# Plotting box plots for numerical features
plt.figure(figsize=(20, 15))

# Box plots for key numerical features
numerical_features_for_boxplot = ['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'DAYS_EMPLOYED', 'TOTALAREA_MODE']

for i, feature in enumerate(numerical_features_for_boxplot, 1):
    plt.subplot(2, 2, i)
    plt.boxplot(data[feature])
    plt.title(f'Boxplot of {feature}')
    plt.tight_layout()

plt.show()

# Plotting scatter plots for numerical features
plt.figure(figsize=(15, 10))

# Scatter plots for pairwise numerical features
pairs_to_plot = [('AMT_INCOME_TOTAL', 'AMT_CREDIT'), ('AMT_INCOME_TOTAL', 'TOTALAREA_MODE'), 
                 ('AMT_CREDIT', 'TOTALAREA_MODE'), ('DAYS_EMPLOYED', 'TOTALAREA_MODE')]

for i, (x, y) in enumerate(pairs_to_plot, 1):
    plt.subplot(2, 2, i)
    plt.scatter(data[x], data[y], alpha=0.5)
    plt.title(f'Scatter plot: {x} vs {y}')
    plt.xlabel(x)
    plt.ylabel(y)
    plt.tight_layout()

plt.show()

# %% [markdown]
# PLOT ANALYSIS
#
# Scatter Plot Analysis
#
# AMT_INCOME_TOTAL vs AMT_CREDIT:
# There is a positive correlation between income and credit amount, as expected. Higher incomes tend to be associated with higher credit amounts, though there are some outliers with very high credit amounts.
#
# AMT_INCOME_TOTAL vs TOTALAREA_MODE:
# No obvious pattern emerges here. This suggests that the total area of the property might not have a strong correlation with income levels.
#
# AMT_CREDIT vs TOTALAREA_MODE:
# Similar to the previous scatter plot, there’s no clear relationship between the credit amount and the property area, suggesting that credit approval isn't strongly tied to property area.
#
# DAYS_EMPLOYED vs TOTALAREA_MODE:
# No significant pattern emerges here either. Employment status or employment history doesn't seem to correlate with the area of the property.
#
# Box Plot Analysis
#
# AMT_INCOME_TOTAL:
# The box plot shows a relatively wide spread, with some potential outliers (particularly high income values), indicating that there are clients with significantly higher incomes than the rest.
#
# AMT_CREDIT:
# Similar to AMT_INCOME_TOTAL, the box plot reveals a wide range of values with extreme outliers, suggesting that some clients have much higher credit amounts compared to others.
#
# DAYS_EMPLOYED:
# The box plot shows a concentration of values close to zero, indicating many clients are either not employed or have negative values indicating non-usage of the feature.

# %%
# Save the cleaned and transformed DataFrame to a new CSV file
data.to_csv('cleaned_transformed_data.csv', index=False)

print("Data has been saved to 'cleaned_transformed_data.csv' successfully!")
# Out:
# Data has been saved to 'cleaned_transformed_data.csv' successfully!

# %%
print(data)
# Out:
#          TARGET  CNT_CHILDREN  CNT_FAM_MEMBERS  CODE_GENDER  FLAG_OWN_CAR  \
# 0     -0.296336     -0.570760        -0.163938            1             1
# 1     -0.296336     -0.570760        -0.163938            0             0
# 2     -0.296336     -0.570760        -0.163938            1             0
# 3     -0.296336      3.559616         3.119732            0             0
# 4     -0.296336     -0.570760        -0.163938            0             1
# ...         ...           ...              ...          ...           ...
# 30741  3.374550     -0.570760        -0.163938            0             0
# 30742  3.374550      2.182824         2.025175            1             1
# 30743  3.374550     -0.570760        -0.163938            1             0
# 30744  3.374550     -0.570760        -1.258494            1             0
# 30745  3.374550      0.806032         0.930619            0             0
#
#        FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  TOTALAREA_MODE  \
# ...
